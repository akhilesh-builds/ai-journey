# %% [markdown]
# **What stuck:**
# [Your words. Could be: DataFrames are like NumPy 2D arrays but with named
# columns and rows. Reading CSV with pd.read_csv. Inspecting with .head, .tail,
# .columns, .describe. Selecting columns with df['name'] or df[['col1','col2']].
# Selecting rows with .iloc (by integer position) or .loc (by label/condition).
# Creating new columns by arithmetic on existing ones. Sorting with .sort_values.
# Reordering columns by manipulating the column list. Exporting with .to_csv.]
#
# **What was fuzzy:**
# [Be honest. .iloc vs .loc? axis=0 vs axis=1 in other operations? The column-
# list manipulation pattern? Something else? Or "nothing was fuzzy" — also valid.]
#
# **Where I'll see this in AI:**
# [Your one sentence. Hint if stuck: every ML pipeline starts with loading data
# into a DataFrame, inspecting it, filtering bad rows, adding feature columns,
# and either feeding it to NumPy/scikit-learn or saving it back. This is literally
# the first 30 minutes of every data-science notebook on Kaggle.]
