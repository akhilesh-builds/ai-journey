# %% [markdown]
# Block 2 — Ep 9 Refresher: Dot Products & Duality
# No re-watch. Three questions, your own words. You've watched this twice and I pre-taught it Wednesday, so this is a seal, not a re-learn. Let's see what stuck.
# Q1 — The mechanics.
# Given two vectors v = [3, 4] and w = [2, 1], compute their dot product. Show the arithmetic.
# Q2 — The geometric meaning.
# In your own words: what does the dot product tell you about the relationship between two vectors? What does a positive, zero, and negative dot product each mean geometrically?
# Q3 — The AI bridge (the one that matters most).
# Name at least one place the dot product shows up in AI/ML, and in one sentence say what it's doing there.
# Answer all three. "Fuzzy on Q3" or similar is a valid honest answer on any of them. Go

# %% [markdown]
# 1. 3*2 + 4*1 = 10
# 2. Dot product means projection of one vector on the other and then multiplying the length of projection and length of vector projected on. Positive says that vectors are close in same direction. 0 says vectors are perpendicular there is no similarity, negative values says that vectors are in opposite directions
# 3. One thing I can think of is similarity between two words. If words are represented by vectors in 2-d space then the dot product will tell us how similar they are or how close they are in terms of context. If Dot product is positive means they are similar in context, if 0 means there is no similarity and negative meaning they are opposite to each other. this example may not be right but i made it up not using the example from video since I do not remember it
